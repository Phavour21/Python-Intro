# %%
full_name = input("please provide your full name")
age = input("please provide your age")
country = input("please provide your country")
focus_area = input("favourite python use case")
course_goal = input("your goal for this course")
print("PYTHON LEARNER IDENTITY CARD")
print("=" *40)
print("\nHello,", full_name + "!")
print("you are", age, "years old.")
print("you are from", country)
print("my favourite python use case is", focus_area)
print("my goal for this course is", course_goal)
print("=" *40)
print("JUST START,YOU WILL SEE RESULTS!")
print("-" *40)
# Out:
# PYTHON LEARNER IDENTITY CARD
# ========================================
#
# Hello, Omodara Favour!
# you are 29 years old.
# you are from China
# my favourite python use case is Data cleaning
# my goal for this course is to become a professional data scientist
# ========================================
# JUST START,YOU WILL SEE RESULTS!
# ----------------------------------------

# %%
print("python", "is", "fun")
print("2024", "01", "15", sep="-")
print("loading", end="...")
print("completed!")
print()
for i in range(5):
    print("*", end="")
print()
# Out:
# python is fun
# 2024-01-15
# loading...completed!
#
# *****

# %%
questions = [
    "what is a list", "what is an object", "what is a tuple", "what is their diference"
]
for question in questions:
    print("\n" + question, end="?")
# Out:
# what is a list?
# what is an object?
# what is a tuple?
# what is their diference?

# %%
age = 20
if age >= 18:
    print("you are an adult")
    print("you can vote in elections")
    print("age check complete")
else:("not eligible")
# Out:
# you are an adult
# you can vote in elections
# age check complete
