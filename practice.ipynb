# %%
print("hello world!")
print("I am learning python!")
print("programming is fun.")
# Out:
# hello world!
# I am learning python!
# programming is fun.

# %%
print("Thank you mum")
print("Thank you dad")
# Out:
# Thank you mum
# Thank you dad

# %%
student_name = "Favour"
course_name = "Data Science & Ai Programming"
print ("Welcome,",student_name)
print ("you are enrolled in",course_name)
print ("let's start coding!")
# Out:
# Welcome, Favour
# you are enrolled in Data Science & Ai Programming
# let's start coding!

# %%
scores = [85, 92, 78, 88]
average = sum(scores) / len(scores)
print(sum(scores))
print("average score:", average)
# Out:
# 343
# average score: 85.75

# %%
Shoe_price = 80000
if Shoe_price < 50000:
    print("Buy")
else:
    print("Dont buy")
# Out:
# Dont buy

# %%
Python_uses = []
"Web Development"
"Data Science"
"Automation"
"Analysis"
"Human"

print("Phython is used for:")
for use in Python_uses:
    print(" -", use)
print("\nTotal domains:", len(Python_uses))
# Out:
# Phython is used for:
#
# Total domains: 0

# %% [markdown]
# #  Hello, i'm Tomi
# ##  Hello, i'm Tomi
# ###  Hello, i'm Tomi
# ####  Hello, i'm Tomi
#
# - list one
# - list two
